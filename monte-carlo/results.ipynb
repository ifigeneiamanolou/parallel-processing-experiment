# %% [markdown]
# # Performing a monte carlo simulation for multiple random walks using parallel processors

# %%
import benchmark
data = benchmark.run_experiment(1000, 10000)
benchmark.plot_compare(data, 1)
